# %%
import xarray as xr
import pandas as pd
import os

# %%
time=[57]
taxas=["Mammals"]
models=["GAM"]

# %%
years= ['1845', '1990', '1995', '2009', '2010', '2020', '2026', '2032', '2048', '2050','2052', '2056', '2080', '2100', '2150', '2200', '2250']
year_indices = {35: 9, 57: 12, 85: 13}
selected_year = years[year_indices[time[0]]]
if time[0] == 35 or time[0] == 57:
    GCMs = ['GFDL-ESM2M', 'IPSL-CM5A-LR', 'HadGEM2-ES', 'MIROC5']
    bioscen_GCMs = ['GFDL.ESM2M', 'IPSL.CM5A-LR', 'HadGEM2.ES', 'MIROC5']
    scenarios = ["rcp26","rcp60"]
elif time[0] == 85:
    GCMs = ['IPSL-CM5A-LR', 'HadGEM2-ES', 'MIROC5']
    bioscen_GCMs = ['IPSL.CM5A-LR', 'HadGEM2.ES', 'MIROC5']
    scenarios = ["rcp26"]

    
#combinations = list(itertools.product(models, model_names))

for model in models:
    for taxa in taxas:
        print("Taxa", taxa)
        print("Model", model)
        print("Time", time[0])
        for GCM, bioscen_GCM in zip(GCMs, bioscen_GCMs):
            print("GCM", GCM, "bioscen_GCM", bioscen_GCM)
            for scenario in scenarios:
                if scenario == "rcp26":
                    ssprcp_short = "ssp126"
                elif scenario == "rcp60":
                    ssprcp_short = "ssp460"
                print("ssprcp_short", ssprcp_short)

                convcodes = pd.read_csv("/storage/homefs/ch21o450/scripts/BioScenComb/data/IUCN_LUH_converion_table_Carlson.csv")
                dir_habclass = "/storage/homefs/ch21o450/IUCN/Habitat_Classifications/" + taxa + "/"

                dir_species = "/storage/workspaces/wa_climate/climate_trt/data/BioScen15/individual_projections/" + taxa+ "_" + model +"_results_climate/"
                available_file = os.listdir(dir_species)
                available_names = [x.split(".csv")[0] for x in available_file]

                formatted_names = []

                for species_name in available_names[:1]:
                    split_species_name = species_name.split("_")[:2]
                    formatted_species_name = " ".join(split_species_name)
                    formatted_names.append(formatted_species_name)

                results = []
                for i, species_name in enumerate(formatted_names):
                    formatted_species_name = species_name.replace(" ", "_")

                    for file_name in available_file:
                        if formatted_species_name in file_name and model + '_dispersal.csv.xz' in file_name:
                            species_file = file_name
                            species_file2 = [x.split(".csv")[0] for x in species_file] 
                            break
                    else:
                        bioscen_species = None
                        continue

                    bioscen_species = pd.read_csv(dir_species + file_name)

                    available_files_iucn = formatted_species_name + ".csv"
                    if available_files_iucn in os.listdir(dir_habclass):
                        IUCN = pd.read_csv(dir_habclass + available_files_iucn)
                    else:
                        continue

                    lon = bioscen_species["x"]
                    lat = bioscen_species["y"]
                    z = bioscen_species[bioscen_GCM + '_' + scenario + '_' + selected_year]
                    disp4 = bioscen_species["dispersal1"] #dispersal1 is d/4 from hereon thus, called dispersal4
                    val_disp = z* disp4
# Out:
# Taxa Mammals
# Model GAM
# Time 57
# GCM GFDL-ESM2M bioscen_GCM GFDL.ESM2M
# ssprcp_short ssp126
# ssprcp_short ssp460
# GCM IPSL-CM5A-LR bioscen_GCM IPSL.CM5A-LR
# ssprcp_short ssp126
# ssprcp_short ssp460
# GCM HadGEM2-ES bioscen_GCM HadGEM2.ES
# ssprcp_short ssp126
# ssprcp_short ssp460
# GCM MIROC5 bioscen_GCM MIROC5
# ssprcp_short ssp126
# ssprcp_short ssp460

# %%
bioscen_species
# Out:
#             x      y  GFDL.ESM2M_piControl_1845  HadGEM2.ES_piControl_1845  \
# 0     -179.75  65.25                   0.249998                   0.429767
# 1     -179.75  65.75                   0.183058                   0.114092
# 2     -179.75  66.25                   0.011763                   0.007655
# 3     -179.75  66.75                   0.004318                   0.002233
# 4     -179.75  67.25                   0.001005                   0.000107
# ...       ...    ...                        ...                        ...
# 23053  101.75  36.75                        NaN                        NaN
# 23054  107.25  67.25                        NaN                        NaN
# 23055  134.25  46.75                        NaN                        NaN
# 23056  135.25  48.25                        NaN                        NaN
# 23057  135.75  48.75                        NaN                        NaN
#
#        IPSL.CM5A-LR_piControl_1845  MIROC5_piControl_1845  \
# 0                         0.037942               0.151012
# 1                         0.036052               0.155225
# 2                         0.000948               0.031570
# 3                         0.000042               0.005320
# 4                              NaN               0.000223
# ...                            ...                    ...
# 23053                          NaN                    NaN
# 23054                          NaN                    NaN
# 23055                          NaN                    NaN
# 23056                          NaN                    NaN
# 23057                          NaN                    NaN
#
#        GFDL.ESM2M_historical_1990  HadGEM2.ES_historical_1990  \
# 0                        0.469367                    0.327700
# 1                        0.511097                    0.154308
# 2                        0.105427                    0.010465
# 3                        0.023305                    0.003110
# 4                        0.002743                    0.000103
# ...                           ...                         ...
# 23053                         NaN                         NaN
# 23054                         NaN                         NaN
# 23055                         NaN                         NaN
# 23056                         NaN                         NaN
# 23057                         NaN                         NaN
#
#        IPSL.CM5A-LR_historical_1990  MIROC5_historical_1990  ...  \
# 0                          0.258387                0.412357  ...
# 1                          0.306635                0.446588  ...
# 2                          0.014830                0.050957  ...
# 3                          0.000778                0.015538  ...
# 4                          0.000035                0.001243  ...
# ...                             ...                     ...  ...
# 23053                           NaN                     NaN  ...
# 23054                           NaN                     NaN  ...
# 23055                           NaN                     NaN  ...
# 23056                           NaN                     NaN  ...
# 23057                           NaN                     NaN  ...
#
#        HadGEM2.ES_rcp26_2250  IPSL.CM5A-LR_rcp26_2250  MIROC5_rcp26_2250  \
# 0                   0.789315                 0.571203           0.695040
# 1                   0.799318                 0.529443           0.803918
# 2                   0.649680                 0.228830           0.650595
# 3                   0.504435                 0.067173           0.298335
# 4                   0.109795                 0.009762           0.022722
# ...                      ...                      ...                ...
# 23053               0.000002                      NaN                NaN
# 23054               0.000003                      NaN                NaN
# 23055               0.000002                 0.000002                NaN
# 23056               0.000007                 0.000003                NaN
# 23057               0.000003                 0.000005                NaN
#
#        presence  dispersal4  dispersal3  dispersal2  dispersal1  fulldisp  \
# 0           NaN         NaN         NaN         NaN         NaN         1
# 1           NaN         NaN         NaN         NaN         NaN         1
# 2           NaN         NaN         NaN         NaN         NaN         1
# 3           NaN         NaN         NaN         NaN         NaN         1
# 4           NaN         NaN         NaN         NaN         NaN         1
# ...         ...         ...         ...         ...         ...       ...
# 23053       NaN         1.0         NaN         NaN         NaN         1
# 23054       NaN         1.0         NaN         NaN         NaN         1
# 23055       NaN         1.0         1.0         NaN         NaN         1
# 23056       NaN         1.0         1.0         NaN         NaN         1
# 23057       NaN         1.0         1.0         NaN         NaN         1
#
#            areaKM2
# 0      1291.896405
# 1      1267.420563
# 2      1242.846695
# 3      1218.176684
# 4      1193.412424
# ...            ...
# 23053  2468.630417
# 23054  1193.412424
# 23055  2112.242876
# 23056  2052.921527
# 23057  2032.830517
#
# [23058 rows x 118 columns]
