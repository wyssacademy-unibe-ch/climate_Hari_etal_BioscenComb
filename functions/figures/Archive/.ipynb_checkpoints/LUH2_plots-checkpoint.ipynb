# %%
#!/usr/bin/env python3
#pip install  rioxarray==0.3.1
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import rioxarray
import numpy as np
import geopandas as gpd
import cartopy.crs as ccrs
import rasterio
import os
import matplotlib.colors
scriptsdir = os.getcwd()
from scipy.interpolate import griddata
from functools import reduce
import itertools
import argparse
import os

from line_profiler import LineProfiler
import pdb

# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + ssprcps_shorts[l] + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)

# Get the variable names excluding 'time_bnds'
variable_names = [var for var in da_landuse.data_vars.keys() if var != 'time_bnds']

# Get the land use data for the first year
landuse_first_year = da_landuse.isel(time=0)

# Create a figure and axis
fig, ax = plt.subplots()

# Set colors for the variables
colors = plt.cm.tab20c(range(len(variable_names)))

# Iterate over the variables and plot the change from the first year
for i, var_name in enumerate(variable_names):
    variable_data = da_landuse[var_name]
    change = variable_data - landuse_first_year[var_name]
    mean_change = np.mean(change, axis=(1, 2))  # Calculate mean change across grid cells
    ax.plot(mean_change, color=colors[i], label=var_name)

# Set x-axis label
ax.set_xlabel('Time')

# Set y-axis label
ax.set_ylabel('Mean Change in Land')

# Add legend
ax.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/54304144/ipykernel_59451/3497596267.py in <module>
#       4
#       5 # Load the land use dataset
# ----> 6 ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + ssprcps_shorts[l] + ".nc"
#       7 da_landuse = xr.open_dataset(ncfname, decode_times=False)
#       8
#
# NameError: name 'ssprcps_shorts' is not defined

# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + ssprcps_shorts[l] + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)

# Get the variable names excluding 'time_bnds'
variable_names = [var for var in da_landuse.data_vars.keys() if var != 'time_bnds']

# Get the land use data for the first year
landuse_first_year = da_landuse.isel(time=0)

# Create a figure and axis
fig, ax = plt.subplots()

# Set colors for the variables
colors = plt.cm.tab20c(range(len(variable_names)))

# Iterate over the variables and plot the change from the first year
for i, var_name in enumerate(variable_names):
    variable_data = da_landuse[var_name]
    change = variable_data - landuse_first_year[var_name]
    flattened_change = change.values.flatten()
    ax.plot(flattened_change, color=colors[i], label=var_name)

# Set x-axis label
ax.set_xlabel('Time')

# Set y-axis label
ax.set_ylabel('Change in Land Use')

# Add legend
ax.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/54304144/ipykernel_59451/1734947038.py in <module>
#       4
#       5 # Load the land use dataset
# ----> 6 ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + ssprcps_shorts[l] + ".nc"
#       7 da_landuse = xr.open_dataset(ncfname, decode_times=False)
#       8
#
# NameError: name 'ssprcps_shorts' is not defined

# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + ssprcps_shorts[l] + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)

# Get the variable names excluding 'time_bnds'
variable_names = [var for var in da_landuse.data_vars.keys() if var != 'time_bnds']

# Get the land use data for the first year
landuse_first_year = da_landuse.isel(time=0)

# Create a figure and axis
fig, ax = plt.subplots()

# Set colors for the variables
colors = plt.cm.tab20c(range(len(variable_names)))

# Iterate over the variables and plot the difference from the first year
for i, var_name in enumerate(variable_names):
    variable_data = da_landuse[var_name]
    difference = variable_data - landuse_first_year[var_name]
    mean_difference = np.mean(difference, axis=(1, 2))  # Calculate mean difference across grid cells
    ax.plot(mean_difference, color=colors[i], label=var_name)

# Set x-axis label
ax.set_xlabel('Time')
ax.set_ylim([-0.2, 0.2])

# Set y-axis label
ax.set_ylabel('Mean Difference from Time 0')

# Add legend
ax.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/local/54304144/ipykernel_59451/188998107.py in <module>
#       4
#       5 # Load the land use dataset
# ----> 6 ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + ssprcps_shorts[l] + ".nc"
#       7 da_landuse = xr.open_dataset(ncfname, decode_times=False)
#       8
#
# NameError: name 'ssprcps_shorts' is not defined

# %%
import matplotlib.pyplot as plt
import xarray as xr

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + "ssp126" + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)

# Get the variable names excluding 'time_bnds'
variable_names = [var for var in da_landuse.data_vars.keys() if var != 'time_bnds']

# Get the time values
time = da_landuse['time'].values
grid_cell_area_km2 = (111.32 * 0.25) * (111.32 * 0.25) * np.cos(np.deg2rad(da_landuse['lat']))

# Create a figure and axes
fig, ax = plt.subplots()

# Loop over each variable name
for var_name in variable_names:
    # Calculate the change in area for each variable
    change_in_area = (da_landuse[var_name] - da_landuse[var_name].isel(time=0)).sum(dim=('lat', 'lon')) /1e6 # Convert to Mkm^2

    # Plot the change in area over time for each variable
    ax.plot(time, change_in_area, label=var_name)

# Set the x-axis label and y-axis label
ax.set_xlabel('Years')
ax.set_ylabel('Change in Land Area (Mkm²)')

# Set the y-axis limits
ax.set_ylim(-10, 10)

# Move the legend to the right and outside the plot
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + "ssp126" + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)
variable_names = [var for var in da_landuse.data_vars.keys() if var != 'time_bnds']
# Get the time values
time = da_landuse['time'].values

# Calculate the area per grid cell (Mkm²)
grid_cell_area_km2 = (111.32 * 0.25) * (111.32 * 0.25) * np.cos(np.deg2rad(da_landuse['lat']))

# Initialize the modified land use dataset
modified_landuse = da_landuse.copy()

# Loop over the data variables and convert the values to Mkm²
for variable in variable_names:
    modified_landuse[variable] = da_landuse[variable] * grid_cell_area_km2 / 1e6  # Convert to Mkm²

# Calculate the sum of values for each variable
sum_over_values = modified_landuse.sum(dim=[dim for dim in modified_landuse.dims if dim != 'time'])

 
fig, ax = plt.subplots()

# Loop over the data variables and plot the sum of values over time
for variable in variable_names:
    values = sum_over_values[variable].values.flatten()
    ax.plot(time, values, label=variable)

# Set the x-axis label and ticks
ax.set_xlabel('Time')

# Set the y-axis label
ax.set_ylabel('Sum of Values')
ax.set_ylim(-10, 10)

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + "ssp126" + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)
variable_names = [var for var in da_landuse.data_vars.keys() if var != 'time_bnds']
# Get the time values
time = da_landuse['time'].values

# Calculate the area per grid cell (Mkm²)
grid_cell_area_km2 = (111.32 * 0.25) * (111.32 * 0.25) * np.cos(np.deg2rad(da_landuse['lat']))

# Initialize the modified land use dataset
modified_landuse = da_landuse.copy()

# Loop over the data variables and convert the values to Mkm²
for variable in variable_names:
    modified_landuse[variable] = da_landuse[variable] * grid_cell_area_km2 / 1e6  # Convert to Mkm²

# Calculate the sum of values for each variable
sum_over_values = modified_landuse.sum(dim=[dim for dim in modified_landuse.dims if dim != 'time'])


# Calculate the difference to Year 0 for each variable
difference = sum_over_values - sum_over_values.isel(time=0)

# Create a figure and axes
fig, ax = plt.subplots()

# Loop over the variable names
for variable in variable_names:
    # Get the difference values for the current variable
    values = difference[variable].values

    # Plot the difference values for the current variable
    ax.plot(time, values, label=variable)

# Set the x-axis label and ticks
ax.set_xlabel('Time')


ax.set_ylim(-10, 10)

# Set the y-axis label
ax.set_ylabel('Change in Land Area (Mkm²)')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + "ssp126" + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)

# Define the category mapping
category_mapping = {
    'cropland': ['c3ann', 'c3per', 'c4ann', 'c4per', 'c3nfx'],
    'pasture': ['pastr', 'range'],
    'forest': ['primf', 'secdf'],
    'natural_land': ['primn', 'secdn']
}

# Get the time values
time = da_landuse['time'].values

# Calculate the area per grid cell (Mkm²)
grid_cell_area_km2 = (111.32 * 0.25) * (111.32 * 0.25) * np.cos(np.deg2rad(da_landuse['lat']))

# Initialize the modified land use dataset
modified_landuse = da_landuse.copy()

# Loop over the data variables and convert the values to Mkm²
for variable in da_landuse.data_vars:
    modified_landuse[variable] = da_landuse[variable] * grid_cell_area_km2 / 1e6  # Convert to Mkm²

# Calculate the sum of values for each variable
sum_over_values = modified_landuse.sum(dim=[dim for dim in modified_landuse.dims if dim != 'time'])

# Calculate the difference to Year 0 for each variable
difference = sum_over_values - sum_over_values.isel(time=0)

# Create a new dataset for sum over categories
sum_over_categories = xr.Dataset()

# Sum the differences for cropland category
sum_over_categories['cropland'] = difference['c3ann'] + difference['c3per'] + difference['c4ann'] + difference['c4per'] + difference['c3nfx']

# Sum the differences for pasture category
sum_over_categories['pasture'] = difference['pastr'] + difference['range']

# Sum the differences for forest category
sum_over_categories['forest'] = difference['primf'] + difference['secdf']

# Sum the differences for natural_land category
sum_over_categories['natural_land'] = difference['primn'] + difference['secdn']

# Calculate the difference to Year 0 for each category
difference = sum_over_categories - sum_over_categories.isel(time=0)

# Create a figure and axes
fig, ax = plt.subplots()

# Loop over the categories
for category in category_mapping:
    # Get the difference values for the current category
    values = difference[category].values

    # Plot the difference values for the current category
    ax.plot(time, values, label=category)

# Set the x-axis label and ticks
ax.set_xlabel('Time')

# Set the y-axis label
ax.set_ylabel('Change in Land Area (Mkm²)')

# Set the y-axis limits
ax.set_ylim(-10, 10)

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# Load the land use dataset
ncfname = "/storage/workspaces/wa_climate/climate_trt/chari/LUH2/remapped_luh2_" + "ssp460" + ".nc"
da_landuse = xr.open_dataset(ncfname, decode_times=False)

# Define the category mapping
category_mapping = {
    'cropland': ['c3ann', 'c3per', 'c4ann', 'c4per', 'c3nfx'],
    'pasture': ['pastr', 'range'],
    'forest': ['primf', 'secdf'],
    'natural_land': ['primn', 'secdn']
}

# Get the time values
time = da_landuse['time'].values

# Calculate the area per grid cell (Mkm²)
grid_cell_area_km2 = (111.32 * 0.25) * (111.32 * 0.25) * np.cos(np.deg2rad(da_landuse['lat']))

# Initialize the modified land use dataset
modified_landuse = da_landuse.copy()

# Loop over the data variables and convert the values to Mkm²
for variable in da_landuse.data_vars:
    modified_landuse[variable] = da_landuse[variable] * grid_cell_area_km2 / 1e6  # Convert to Mkm²

# Calculate the sum of values for each variable
sum_over_values = modified_landuse.sum(dim=[dim for dim in modified_landuse.dims if dim != 'time'])

# Calculate the difference to Year 0 for each variable
difference = sum_over_values - sum_over_values.isel(time=0)

# Create a new dataset for sum over categories
sum_over_categories = xr.Dataset()

# Sum the differences for cropland category
sum_over_categories['cropland'] = difference['c3ann'] + difference['c3per'] + difference['c4ann'] + difference['c4per'] + difference['c3nfx']

# Sum the differences for pasture category
sum_over_categories['pasture'] = difference['pastr'] + difference['range']

# Sum the differences for forest category
sum_over_categories['forest'] = difference['primf'] + difference['secdf']

# Sum the differences for natural_land category
sum_over_categories['natural_land'] = difference['primn'] + difference['secdn']

# Calculate the difference to Year 0 for each category
difference = sum_over_categories - sum_over_categories.isel(time=0)

# Create a figure and axes
fig, ax = plt.subplots()

# Loop over the categories
for category in category_mapping:
    # Get the difference values for the current category
    values = difference[category].values

    # Plot the difference values for the current category
    ax.plot(time, values, label=category)

# Set the x-axis label and ticks
ax.set_xlabel('Time')

# Set the y-axis label
ax.set_ylabel('Change in Land Area (Mkm²)')

# Set the y-axis limits
ax.set_ylim(-10, 10)

# Add a legend
ax.legend()

# Display the plot
plt.show()
