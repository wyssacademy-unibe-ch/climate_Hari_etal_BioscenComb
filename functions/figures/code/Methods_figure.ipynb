# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data for current and future scenarios (adjust as needed)
current_data = np.array([[0.8, 0.3], [0.5, 0]])
future_data = np.array([[0, 0.2], [0.5, 0.5]])
change_climate = future_data - current_data

# Create the subplot for the different conditions
fig, ax = plt.subplots(1, 1, figsize=(4, 4))

# Plot current condition heatmap
sns.heatmap(current_data, ax=ax, cmap='Blues', annot=True, cbar=False)
ax.set_title('Climate Change')
ax.set_ylabel('Probability of Occurrence')

plt.tight_layout()
plt.show()

# %%
# Further adjusting the figure to place the SSP1-RCP2.6 and SSP4-RCP6.0 titles on top of each respective group

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
climate = np.array([[0.8, 0.3], [0.5, 0]])
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
pasture_1 = np.array([[0, 0], [0.5, 0.2]])
cropland_1 = np.array([[0, 0], [0.5, 0.1]])

# Second set of data for SSP4-RCP6.0
forest_2 = np.array([[0.1, 0.5], [0, 0.1]])
non_forested_2 = np.array([[0.2, 0.5], [0, 0.2]])
pasture_2 = np.array([[0, 0], [1, 0.1]])
cropland_2 = np.array([[0.7, 0], [0, 0.6]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(2, 4, figsize=(8, 6))

# Add the main titles above the respective group of heatmaps
fig.text(0.25, 0.95, 'SSP1-RCP2.6', ha='center', fontsize=14)
fig.text(0.75, 0.95, 'SSP4-RCP6.0', ha='center', fontsize=14)

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(climate, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 0].set_title('Climate Change', fontsize=12)
axes[0,0].set_ylabel('Probability of Occurrence', fontsize=10)

sns.heatmap(non_forested_1, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 1].set_title('Non-forested Land', fontsize=12)

sns.heatmap(pasture_1, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 0].set_title('Pasture', fontsize=12)

sns.heatmap(cropland_1, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 1].set_title('Cropland', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(forest_2, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 2].set_title('Forested Land', fontsize=12)

sns.heatmap(non_forested_2, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 3].set_title('Non-forested Land', fontsize=12)

sns.heatmap(pasture_2, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 2].set_title('Pasture', fontsize=12)

sns.heatmap(cropland_2, ax=axes[1, 3], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 3].set_title('Cropland', fontsize=12)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data for current and future scenarios (adjust as needed)
current_data = np.array([[0, 0.3], [0.5, 0.8]])
future_data = np.array([[0, 0.2], [0.5, 0.5]])
change_climate = future_data - current_data

# Create the subplots for the different conditions
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# Plot current condition heatmap
sns.heatmap(current_data, ax=axes[0], cmap='Blues', annot=True, cbar=False)
axes[0].set_title('Climate Change')
axes[0].set_ylabel('Probability of Occurrence')

# Plot future condition heatmap
sns.heatmap(future_data, ax=axes[1], cmap='Blues', annot=True, cbar=False)
axes[1].set_title('Land Use Change')
axes[1].set_ylabel('Fraction of Gridcell')

# Plot climate change impact heatmap
sns.heatmap(change_climate, ax=axes[2], cmap='RdBu', annot=True, cbar=False, center=0)
axes[2].set_title('Climate and Land Use Change')
axes[2].set_ylabel('Weighted Probability of Occurrence')
# Adding text between subplots
fig.text(0.37, 0.5, '×', fontsize=20, ha='center', va='center')
fig.text(0.64, 0.5, '=', fontsize=20, ha='center', va='center')

# Adding an arrow between plots to indicate transition
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

# Add an annotation arrow between plots
#plt.annotate('', xy=(0.31, 0.5), xycoords='axes fraction', xytext=(0.67, 0.5),
         #    arrowprops=dict(arrowstyle="->", lw=2, color='black'))

#plt.annotate('Climate & LU Change', xy=(0.5, 0.55), xycoords='figure fraction')

#plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data for current and future scenarios (adjust as needed)
forest = np.array([[0.3, 0.8], [0, 0.2]])
non_forested = np.array([[0.7, 0.2], [0, 0.5]])
pasture = np.array([[0, 0], [0.5, 0.2]])
cropland=np.array([[0, 0], [0.5, 0.1]])
change_climate = future_data - current_data

# Create the subplots for the different conditions
fig, axes = plt.subplots(2, 2, figsize=(8, 8))

# Plot current condition heatmap (Forested Land)
sns.heatmap(forest, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False)
axes[0, 0].set_title('Forested Land ')
axes[0, 0].set_ylabel('Fraction of Gridcell')

# Plot future condition heatmap (Non-forested Land)
sns.heatmap(non_forested, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False)
axes[0, 1].set_title('Non-forested Land')
axes[0, 1].set_ylabel('Fraction of Gridcell')

# Plot pasture heatmap
sns.heatmap(pasture, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 0].set_title('Pasture')
axes[1, 0].set_ylabel('Fraction of Gridcell')

# Plot cropland heatmap
sns.heatmap(cropland, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 1].set_title('Cropland')
axes[1, 1].set_ylabel('Fraction of Gridcell')
fig.suptitle('SSP1-RCP2.6', fontsize=16)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data for current and future scenarios (adjust as needed)
forest = np.array([[0.1, 0.5], [0, 0.1]])
non_forested = np.array([[0.2, 0.5], [0, 0.2]])
pasture = np.array([[0, 0], [1, 0.1]])
cropland=np.array([[0.7, 0], [0, 0.6]])
change_climate = future_data - current_data

# Create the subplots for the different conditions
fig, axes = plt.subplots(2, 2, figsize=(8, 8))

# Plot current condition heatmap (Forested Land)
sns.heatmap(forest, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False)
axes[0, 0].set_title('Forested Land ')
axes[0, 0].set_ylabel('Fraction of Gridcell')

# Plot future condition heatmap (Non-forested Land)
sns.heatmap(non_forested, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False)
axes[0, 1].set_title('Non-forested Land')
axes[0, 1].set_ylabel('Fraction of Gridcell')

# Plot pasture heatmap
sns.heatmap(pasture, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 0].set_title('Pasture')
axes[1, 0].set_ylabel('Fraction of Gridcell')

# Plot cropland heatmap
sns.heatmap(cropland, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 1].set_title('Cropland')
axes[1, 1].set_ylabel('Fraction of Gridcell')
fig.suptitle('SSP4-RCP6.0', fontsize=16)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
pasture_1 = np.array([[0, 0], [0.5, 0.2]])
cropland_1 = np.array([[0, 0], [0.5, 0.1]])

# Second set of data for SSP4-RCP6.0
forest_2 = np.array([[0.1, 0.5], [0, 0.1]])
non_forested_2 = np.array([[0.2, 0.5], [0, 0.2]])
pasture_2 = np.array([[0, 0], [1, 0.1]])
cropland_2 = np.array([[0.7, 0], [0, 0.6]])

# Create the figure and subplots for both datasets side by side
fig, axes = plt.subplots(2, 4, figsize=(6, 3))

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False)
axes[0, 0].set_title('Forested Land')
axes[0, 0].set_ylabel('Fraction of Gridcell')

sns.heatmap(non_forested_1, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False)
axes[0, 1].set_title('Non-forested Land')

sns.heatmap(pasture_1, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 0].set_title('Pasture')
axes[1, 0].set_ylabel('Fraction of Gridcell')

sns.heatmap(cropland_1, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 1].set_title('Cropland')

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(forest_2, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False)
axes[0, 2].set_title('Forested Land')

sns.heatmap(non_forested_2, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False)
axes[0, 3].set_title('Non-forested Land')

sns.heatmap(pasture_2, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 2].set_title('Pasture')

sns.heatmap(cropland_2, ax=axes[1, 3], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 3].set_title('Cropland')

# Add main titles for each set
fig.suptitle('Comparison of SSP1-RCP2.6 and SSP4-RCP6.0', fontsize=12)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Further adjusting the figure to place the SSP1-RCP2.6 and SSP4-RCP6.0 titles on top of each respective group

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
climate = np.array([[0.8, 0.3], [0.5, 0]])


# Second set of data for SSP4-RCP6.0
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]]) 
climate = np.array([[0.8, 0.3], [0.5, 0]])
# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 4, figsize=(7, 2.5))

# Add the main titles above the respective group of heatmaps
fig.text(0.5, 0.95, 'Exemplary for SSP1-RCP2.6', ha='center', fontsize=14)


# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[ 1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 1].set_title('Climate Change', fontsize=12)


# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(non_forested_1, ax=axes[ 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 2].set_title('Non-Forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[ 3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 3].set_title('Climate Change', fontsize=12)




fig.text(0.255, 0.5, '×', fontsize=16, ha='center', va='center')
fig.text(0.745, 0.5, '×', fontsize=16, ha='center', va='center')
# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
climate = np.array([[0.8, 0.3], [0.5, 0]])
mult1 = np.array([[0.24, 0.24], [0, 0]])

# Second set of data for SSP4-RCP6.0
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]]) 
climate = np.array([[0.8, 0.3], [0.5, 0]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5))

# Add the main titles above the respective group of heatmaps

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title(' Climate', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(mult1, ax=axes[2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate and Forested Land', fontsize=12)


# Add equal signs between the plots
fig.text(0.33, 0.5, '×', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
climate = np.array([[0.8, 0.3], [0.5, 0]])
mult1 = np.array([[0.24, 0.24], [0, 0]])

# Second set of data for SSP4-RCP6.0
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]]) 
climate = np.array([[0.8, 0.3], [0.5, 0]])
mult2 = np.array([[0.56, 0.06], [0, 0]])
# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5))

# Add the main titles above the respective group of heatmaps

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(non_forested_1, ax=axes[0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Non-forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title(' Climate', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(mult2, ax=axes[2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate and Non-forested Land', fontsize=12)


# Add equal signs between the plots
fig.text(0.33, 0.5, '×', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Data for SSP1-RCP2.6 (Forested Land) and SSP4-RCP6.0 (Non-forested Land)
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
climate = np.array([[0.8, 0.3], [0.5, 0]])

# Multiplication results for both cases
mult1 = np.array([[0.24, 0.24], [0, 0]])
mult2 = np.array([[0.56, 0.06], [0, 0]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(2, 3, figsize=(9, 5))

# Add the main titles above the respective group of heatmaps

# Plot SSP1-RCP2.6 heatmaps (Forested Land)
sns.heatmap(forest_1, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0, 0].set_title('Forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0, 1].set_title('Climate', fontsize=12)

sns.heatmap(mult1, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0, 2].set_title('Climate and Forested Land', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps (Non-forested Land)
sns.heatmap(non_forested_1, ax=axes[1, 0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1, 0].set_title('Non-forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[1, 1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1, 1].set_title('Climate', fontsize=12)

sns.heatmap(mult2, ax=axes[1, 2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1, 2].set_title('Climate and Non-forested Land', fontsize=12)

# Add multiplication and equal signs between the plots for both rows
fig.text(0.33, 0.75, '×', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.75, '=', fontsize=16, ha='center', va='center')

fig.text(0.33, 0.25, '×', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.25, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Further adjusting the figure to add a plus sign between the totals and show a third row with the final total
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
climate = np.array([[0.8, 0.3], [0.5, 0]])
mult1 = np.array([[0.24, 0.24], [0, 0]])

# Second set of data for SSP4-RCP6.0
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]]) 
climate = np.array([[0.8, 0.3], [0.5, 0]])
# Calculating the total for the third row
total = mult1 + mult2

# Create the figure and subplots for both datasets side by side, with an additional row for the total
fig, axes = plt.subplots(3, 3, figsize=(8, 6))

# Plot SSP1-RCP2.6 heatmaps (Forested Land)
sns.heatmap(forest_1, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0, 0].set_title('Forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0, 1].set_title('Climate', fontsize=12)

sns.heatmap(mult1, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0, 2].set_title('Climate and Forested Land', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps (Non-forested Land)
sns.heatmap(non_forested_1, ax=axes[1, 0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1, 0].set_title('Non-forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[1, 1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1, 1].set_title('Climate', fontsize=12)

sns.heatmap(mult2, ax=axes[1, 2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1, 2].set_title('Climate and Non-forested Land', fontsize=12)

# Add the final total in the third row with a different color
sns.heatmap(total, ax=axes[2, 2], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2, 2].set_title('Climate and Land Use Change', fontsize=12)

axes[2, 0].axis('off')
axes[2, 1].axis('off')

# Add multiplication and equal signs between the plots for both rows
fig.text(0.33, 0.8, '×', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.8, '=', fontsize=16, ha='center', va='center')

fig.text(0.33, 0.45, '×', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.45, '=', fontsize=16, ha='center', va='center')

# Add a plus sign between the two results in the third row
fig.text(0.8259, 0.64, '+', fontsize=16, ha='center', va='center')
fig.text(0.8259, 0.33, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

total = mult1 + mult2

climate

landuse = total-climate
# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5))

# Add the main titles above the respective group of heatmaps

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(total, ax=axes[0], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Climate and Land Use Change', fontsize=12)

sns.heatmap(climate, ax=axes[1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('Climate', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(landuse, ax=axes[2], cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Land Use Change', fontsize=12)


# Add equal signs between the plots
fig.text(0.33, 0.5, '-', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
# Further adjusting the figure to place the SSP1-RCP2.6 and SSP4-RCP6.0 titles on top of each respective group

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
mult1 = np.array([[0.24, 0.24], [0, 0]])


# Second set of data for SSP4-RCP6.0
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]]) 
mult2 = np.array([[0.56, 0.06], [0, 0]])
# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 4, figsize=(7, 2.5))

# Add the main titles above the respective group of heatmaps
fig.text(0.5, 0.95, 'Exemplary for SSP1-RCP2.6', ha='center', fontsize=14)


# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Forested Land', fontsize=12)

sns.heatmap(mult1, ax=axes[ 1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 1].set_title('Climate Change', fontsize=12)


# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(non_forested_1, ax=axes[ 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 2].set_title('Non-Forested Land', fontsize=12)

sns.heatmap(mult2, ax=axes[ 3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 3].set_title('Climate Change', fontsize=12)




fig.text(0.255, 0.5, '=', fontsize=16, ha='center', va='center')
fig.text(0.745, 0.5, '=', fontsize=16, ha='center', va='center')
# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
mult1 = np.array([[0.24, 0.24], [0, 0]])

# Second set of data for SSP4-RCP6.0
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
mult2 = np.array([[0.56, 0.06], [0, 0]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 4, figsize=(9, 2.5))

# Add the main titles above the respective group of heatmaps
fig.text(0.5, 0.95, 'Exemplary for SSP1-RCP2.6', ha='center', fontsize=14)

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Forested Land', fontsize=12)

sns.heatmap(mult1, ax=axes[1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(non_forested_1, ax=axes[2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Non-Forested Land', fontsize=12)

sns.heatmap(mult2, ax=axes[3], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[3].set_title('', fontsize=12)

# Add equal signs between the plots
fig.text(0.255, 0.5, '=', fontsize=16, ha='center', va='center')
fig.text(0.745, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6

mult1 = np.array([[0.24, 0.24], [0, 0]])

# Second set of data for SSP4-RCP6.0

mult2 = np.array([[0.56, 0.06], [0, 0]])

total=  np.array([[0.8, 0.3], [0, 0]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5))

# Add the main titles above the respective group of heatmaps
fig.text(0.5, 0.95, 'Exemplary for SSP1-RCP2.6', ha='center', fontsize=14)

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(mult1, ax=axes[0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Climate and Forested Land', fontsize=12)

sns.heatmap(mult2, ax=axes[1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title(' Climate and Non-Forested Land', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(total, ax=axes[2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate and Land Use Change', fontsize=12)


# Add equal signs between the plots
fig.text(0.33, 0.5, '+', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6

mult1 = np.array([[0.24, 0.24], [0, 0]])

# Second set of data for SSP4-RCP6.0

mult2 = np.array([[0.56, 0.06], [0, 0]])

total=  np.array([[0.8, 0.3], [0, 0]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5))

# Add the main titles above the respective group of heatmaps

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(mult1, ax=axes[0], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Climate and Forested Land', fontsize=12)

sns.heatmap(mult2, ax=axes[1], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title(' Climate and Non-Forested Land', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(total, ax=axes[2], cmap='Blues', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate and Land Use Change', fontsize=12)


# Add equal signs between the plots
fig.text(0.33, 0.5, '+', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
# Further adjusting the figure to place the SSP1-RCP2.6 and SSP4-RCP6.0 titles on top of each respective group

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
climate = np.array([[0.8, 0.3], [0.5, 0]])
mult_1 = climate * forest_1


# Second set of data for SSP4-RCP6.0
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]]) 
climate = np.array([[0.8, 0.3], [0.5, 0]])

mult_2 = non_forested_1 * climate
# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(2, 4, figsize=(7, 2.5))

# Add the main titles above the respective group of heatmaps
fig.text(0.5, 0.95, 'Exemplary for SSP1-RCP2.6', ha='center', fontsize=14)


# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0,0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0,0].set_title('Forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[ 0,1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 0,1].set_title('Climate Change', fontsize=12)

sns.heatmap(mult_1, ax=axes[ 0,1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 1,0.5].set_title('Mult', fontsize=12)


sns.heatmap(climate, ax=axes[ 0,1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 0,2].set_title('Climate Change', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(non_forested_1, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 3].set_title('Non-Forested Land', fontsize=12)

sns.heatmap(climate, ax=axes[ 0,3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 2,1.5].set_title('Climate Change', fontsize=12)


sns.heatmap(mult_2, ax=axes[ 0,3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[ 1,3].set_title('Mult', fontsize=12)

fig.text(0.255, 0.5, '×', fontsize=16, ha='center', va='center')
fig.text(0.745, 0.5, '×', fontsize=16, ha='center', va='center')
# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[104], line 33
#      30 axes[ 0,1].set_title('Climate Change', fontsize=12)
#      32 sns.heatmap(mult_1, ax=axes[ 0,1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
# ---> 33 axes[ 1,0.5].set_title('Climate Change', fontsize=12)
#      36 sns.heatmap(climate, ax=axes[ 0,1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
#      37 axes[ 0,2].set_title('Climate Change', fontsize=12)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Data for Climate Change heatmap
climate_change = np.array([[0.8, 0.3], [0.5, 0.0]])

# Data for SSP1-RCP2.6
ssp1_forest = np.array([[0.3, 0.8], [0, 0.2]])
ssp1_non_forested = np.array([[0.7, 0.2], [0, 0.5]])

# Data for SSP4-RCP6.0
ssp4_forest = np.array([[0.1, 0.5], [0, 0.1]])
ssp4_non_forested = np.array([[0.2, 0.5], [0, 0.2]])

# Perform element-wise multiplication of Climate Change with SSP1-RCP2.6 and SSP4-RCP6.0
ssp1_forest_result = ssp1_forest * climate_change
ssp1_non_forested_result = ssp1_non_forested * climate_change
ssp4_forest_result = ssp4_forest * climate_change
ssp4_non_forested_result = ssp4_non_forested * climate_change

# Calculate the total for each SSP scenario by summing the multiplied matrices
ssp1_total = ssp1_forest_result + ssp1_non_forested_result
ssp4_total = ssp4_forest_result + ssp4_non_forested_result

# Create a figure with subplots
fig, axes = plt.subplots(2, 4, figsize=(12, 6))

# Plot SSP1-RCP2.6
sns.heatmap(ssp1_forest, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False)
axes[0, 0].set_title('Forested Land (SSP1)')

sns.heatmap(climate_change, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False)
axes[0, 1].set_title('Climate Change (SSP1)')

sns.heatmap(ssp1_non_forested, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False)
axes[0, 2].set_title('Non-Forested Land (SSP1)')

sns.heatmap(climate_change, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False)
axes[0, 3].set_title('Climate Change (SSP1)')

# Plot SSP4-RCP6.0
sns.heatmap(ssp4_forest, ax=axes[1, 0], cmap='Blues', annot=True, cbar=False)
axes[1, 0].set_title('Forested Land (SSP4)')

sns.heatmap(climate_change, ax=axes[1, 1], cmap='Blues', annot=True, cbar=False)
axes[1, 1].set_title('Climate Change (SSP4)')

sns.heatmap(ssp4_non_forested, ax=axes[1, 2], cmap='Blues', annot=True, cbar=False)
axes[1, 2].set_title('Non-Forested Land (SSP4)')

sns.heatmap(climate_change, ax=axes[1, 3], cmap='Blues', annot=True, cbar=False)
axes[1, 3].set_title('Climate Change (SSP4)')

# Add plots for the totals below
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

sns.heatmap(ssp1_total, ax=axes[0], cmap='Blues', annot=True, cbar=False)
axes[0].set_title('Total SSP1')

sns.heatmap(ssp4_total, ax=axes[1], cmap='Blues', annot=True, cbar=False)
axes[1].set_title('Total SSP4')

plt.tight_layout()
plt.show()

# %%
# Further adjusting the figure to place the SSP1-RCP2.6 and SSP4-RCP6.0 titles on top of each respective group

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
pasture_1 = np.array([[0, 0], [0.5, 0.2]])
cropland_1 = np.array([[0, 0], [0.5, 0.1]])

# Second set of data for SSP4-RCP6.0
forest_2 = np.array([[0.1, 0.5], [0, 0.1]])
non_forested_2 = np.array([[0.2, 0.5], [0, 0.2]])
pasture_2 = np.array([[0, 0], [1, 0.1]])
cropland_2 = np.array([[0.7, 0], [0, 0.6]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(2, 4, figsize=(6, 4))

# Add the main titles above the respective group of heatmaps
fig.text(0.25, 0.95, 'SSP1-RCP2.6', ha='center', fontsize=14)
fig.text(0.75, 0.95, 'SSP4-RCP6.0', ha='center', fontsize=14)

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 0].set_title('Forested Land', fontsize=12)

sns.heatmap(non_forested_1, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 1].set_title('Non-forested Land', fontsize=12)

sns.heatmap(pasture_1, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 0].set_title('Pasture', fontsize=12)

sns.heatmap(cropland_1, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 1].set_title('Cropland', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(forest_2, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 2].set_title('Forested Land', fontsize=12)

sns.heatmap(non_forested_2, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 3].set_title('Non-forested Land', fontsize=12)

sns.heatmap(pasture_2, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 2].set_title('Pasture', fontsize=12)

sns.heatmap(cropland_2, ax=axes[1, 3], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 3].set_title('Cropland', fontsize=12)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Data for Climate Change heatmap
climate_change = np.array([[0.8, 0.3], [0.5, 0.0]])

# Data for SSP1-RCP2.6
ssp1_forest = np.array([[0.3, 0.8], [0, 0.2]])
ssp1_non_forested = np.array([[0.7, 0.2], [0, 0.5]])
ssp1_pasture = np.array([[0, 0], [0.5, 0.2]])
ssp1_cropland = np.array([[0, 0], [0.5, 0.1]])

# Data for SSP4-RCP6.0
ssp4_forest = np.array([[0.1, 0.5], [0, 0.1]])
ssp4_non_forested = np.array([[0.2, 0.5], [0, 0.2]])
ssp4_pasture = np.array([[0, 0], [1, 0.1]])
ssp4_cropland = np.array([[0.7, 0], [0, 0.6]])

# Perform element-wise multiplication of Climate Change with each land-use gridcell
ssp1_forest_result = ssp1_forest * climate_change
ssp1_non_forested_result = ssp1_non_forested * climate_change
ssp1_pasture_result = ssp1_pasture * climate_change
ssp1_cropland_result = ssp1_cropland * climate_change

ssp4_forest_result = ssp4_forest * climate_change
ssp4_non_forested_result = ssp4_non_forested * climate_change
ssp4_pasture_result = ssp4_pasture * climate_change
ssp4_cropland_result = ssp4_cropland * climate_change

# Create a figure with subplots for the results
fig, axes = plt.subplots(2, 4, figsize=(12, 4))

# Plot SSP1-RCP2.6 results
sns.heatmap(ssp1_forest_result, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.1f')
axes[0, 0].set_title('Forested Land (SSP1)')

sns.heatmap(ssp1_non_forested_result, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.1f')
axes[0, 1].set_title('Non-forested Land (SSP1)')

sns.heatmap(ssp1_pasture_result, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, fmt='.1f', center=0)
axes[1, 0].set_title('Pasture (SSP1)')

sns.heatmap(ssp1_cropland_result, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, fmt='.1f', center=0)
axes[1, 1].set_title('Cropland (SSP1)')

# Plot SSP4-RCP6.0 results
sns.heatmap(ssp4_forest_result, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.1f')
axes[0, 2].set_title('Forested Land (SSP4)')

sns.heatmap(ssp4_non_forested_result, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False, fmt='.1f')
axes[0, 3].set_title('Non-forested Land (SSP4)')

sns.heatmap(ssp4_pasture_result, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, fmt='.1f', center=0)
axes[1, 2].set_title('Pasture (SSP4)')

sns.heatmap(ssp4_cropland_result, ax=axes[1, 3], cmap='RdBu', annot=True, cbar=False, fmt='.1f', center=0)
axes[1, 3].set_title('Cropland (SSP4)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Further adjusting the figure to place the SSP1-RCP2.6 and SSP4-RCP6.0 titles on top of each respective group

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
pasture_1 = np.array([[0, 0], [0.5, 0.2]])
cropland_1 = np.array([[0, 0], [0.5, 0.1]])

# Second set of data for SSP4-RCP6.0
forest_2 = np.array([[0.1, 0.5], [0, 0.1]])
non_forested_2 = np.array([[0.2, 0.5], [0, 0.2]])
pasture_2 = np.array([[0, 0], [1, 0.1]])
cropland_2 = np.array([[0.7, 0], [0, 0.6]])

# Create the figure and subplots for both datasets side by side, with titles on top
fig, axes = plt.subplots(2, 4, figsize=(6, 4))

# Add the main titles above the respective group of heatmaps
fig.text(0.25, 0.95, 'SSP1-RCP2.6', ha='center', fontsize=14)
fig.text(0.75, 0.95, 'SSP4-RCP6.0', ha='center', fontsize=14)

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 0].set_title('Forested Land', fontsize=12)

sns.heatmap(non_forested_1, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 1].set_title('Non-forested Land', fontsize=12)

sns.heatmap(pasture_1, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 0].set_title('Pasture', fontsize=12)

sns.heatmap(cropland_1, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 1].set_title('Cropland', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(forest_2, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 2].set_title('Forested Land', fontsize=12)

sns.heatmap(non_forested_2, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 3].set_title('Non-forested Land', fontsize=12)

sns.heatmap(pasture_2, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 2].set_title('Pasture', fontsize=12)

sns.heatmap(cropland_2, ax=axes[1, 3], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 3].set_title('Cropland', fontsize=12)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
# Further adjusting the figure to make the heatmaps even smaller and add two separate titles

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
pasture_1 = np.array([[0, 0], [0.5, 0.2]])
cropland_1 = np.array([[0, 0], [0.5, 0.1]])

# Second set of data for SSP4-RCP6.0
forest_2 = np.array([[0.1, 0.5], [0, 0.1]])
non_forested_2 = np.array([[0.2, 0.5], [0, 0.2]])
pasture_2 = np.array([[0, 0], [1, 0.1]])
cropland_2 = np.array([[0.7, 0], [0, 0.6]])

# Create the figure and subplots for both datasets side by side, with even smaller heatmaps and separate titles
fig, axes = plt.subplots(2, 4, figsize=(12, 4))

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 0].set_title('Forested Land', fontsize=8)
axes[0, 0].set_ylabel('SSP1-RCP2.6', fontsize=12)

sns.heatmap(non_forested_1, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 1].set_title('Non-forested Land', fontsize=8)

sns.heatmap(pasture_1, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 0].set_title('Pasture', fontsize=8)

sns.heatmap(cropland_1, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 1].set_title('Cropland', fontsize=8)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(forest_2, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 2].set_title('Forested Land', fontsize=8)
axes[0, 2].set_ylabel('SSP4-RCP6.0', fontsize=12)

sns.heatmap(non_forested_2, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[0, 3].set_title('Non-forested Land', fontsize=8)

sns.heatmap(pasture_2, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 2].set_title('Pasture', fontsize=8)

sns.heatmap(cropland_2, ax=axes[1, 3], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 12}, square=True)
axes[1, 3].set_title('Cropland', fontsize=8)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
# Adjusting the figure to make the heatmaps smaller and increase the size of the numbers

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# First set of data for SSP1-RCP2.6
forest_1 = np.array([[0.3, 0.8], [0, 0.2]])
non_forested_1 = np.array([[0.7, 0.2], [0, 0.5]])
pasture_1 = np.array([[0, 0], [0.5, 0.2]])
cropland_1 = np.array([[0, 0], [0.5, 0.1]])

# Second set of data for SSP4-RCP6.0
forest_2 = np.array([[0.1, 0.5], [0, 0.1]])
non_forested_2 = np.array([[0.2, 0.5], [0, 0.2]])
pasture_2 = np.array([[0, 0], [1, 0.1]])
cropland_2 = np.array([[0.7, 0], [0, 0.6]])

# Create the figure and subplots for both datasets side by side, with smaller heatmaps and larger text
fig, axes = plt.subplots(2, 4, figsize=(12, 6))

# Plot SSP1-RCP2.6 heatmaps
sns.heatmap(forest_1, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[0, 0].set_title('Forested Land (SSP1-RCP2.6)', fontsize=10)
axes[0, 0].set_ylabel('')

sns.heatmap(non_forested_1, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[0, 1].set_title('Non-forested Land (SSP1-RCP2.6)', fontsize=10)

sns.heatmap(pasture_1, ax=axes[1, 0], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[1, 0].set_title('Pasture (SSP1-RCP2.6)', fontsize=10)

sns.heatmap(cropland_1, ax=axes[1, 1], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[1, 1].set_title('Cropland (SSP1-RCP2.6)', fontsize=10)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(forest_2, ax=axes[0, 2], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[0, 2].set_title('Forested Land (SSP4-RCP6.0)', fontsize=10)

sns.heatmap(non_forested_2, ax=axes[0, 3], cmap='Blues', annot=True, cbar=False, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[0, 3].set_title('Non-forested Land (SSP4-RCP6.0)', fontsize=10)

sns.heatmap(pasture_2, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[1, 2].set_title('Pasture (SSP4-RCP6.0)', fontsize=10)

sns.heatmap(cropland_2, ax=axes[1, 3], cmap='RdBu', annot=True, cbar=False, center=0, fmt='.1f', annot_kws={"size": 14}, square=True)
axes[1, 3].set_title('Cropland (SSP4-RCP6.0)', fontsize=10)

# Add main titles for each set
fig.suptitle('Comparison of SSP1-RCP2.6 and SSP4-RCP6.0', fontsize=16)

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data for heatmaps
climate_change = np.array([[0, 0.3], [0.5, 0]])
land_use_change = np.array([[0, 0.2], [0.5, 0.5]])
climate_land_use_change = np.array([[0, -0.1], [0, 0.5]])

# Create the subplots for heatmaps
fig, axes = plt.subplots(1, 3, figsize=(16, 6))

# Plot each heatmap
sns.heatmap(climate_change, ax=axes[0], cmap='Blues', annot=True, cbar=False)
axes[0].set_title('Climate Change')
axes[0].set_ylabel('Probability of Occurrence')

sns.heatmap(land_use_change, ax=axes[1], cmap='Blues', annot=True, cbar=False)
axes[1].set_title('Land Use Change')
axes[1].set_ylabel('Fraction of Gridcell')

sns.heatmap(climate_land_use_change, ax=axes[2], cmap='RdBu', annot=True, cbar=False, center=0)
axes[2].set_title('Climate and Land Use Change')
axes[2].set_ylabel('Weighted Probability of Occurrence')

# Adjust layout of heatmaps
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

# Adjust positions of the "LUH2 Conversion" and "IUCN Habitats" text
plt.annotate('LUH2\nConversion', xy=(0.4, 0.88), xycoords='figure fraction', fontsize=12, ha='center', 
             arrowprops=dict(arrowstyle="->", lw=1.5, color='black'))

plt.annotate('IUCN\nHabitats', xy=(0.6, 0.88), xycoords='figure fraction', fontsize=12, ha='center', 
             arrowprops=dict(arrowstyle="->", lw=1.5, color='black'))

# Add main process diagram annotations
plt.annotate('Probability of Occurrence', xy=(0.15, 0.95), xycoords='figure fraction', fontsize=12, ha='center', 
             arrowprops=dict(arrowstyle="->", lw=1.5, color='black', connectionstyle="arc3,rad=-0.3"))

plt.annotate('Fraction of Gridcell', xy=(0.5, 0.95), xycoords='figure fraction', fontsize=12, ha='center', 
             arrowprops=dict(arrowstyle="->", lw=1.5, color='black', connectionstyle="arc3,rad=-0.3"))

plt.annotate('Weighted Probability of Occurrence', xy=(0.85, 0.95), xycoords='figure fraction', fontsize=12, ha='center', 
             arrowprops=dict(arrowstyle="->", lw=1.5, color='black', connectionstyle="arc3,rad=-0.3"))

# Add funnel-like arrows going down to the final weighted probability
plt.annotate('', xy=(0.75, 0.5), xytext=(0.75, 0.4), xycoords='figure fraction', 
             arrowprops=dict(arrowstyle="simple", lw=1.5, color='black'))

plt.annotate('', xy=(0.25, 0.5), xytext=(0.25, 0.4), xycoords='figure fraction', 
             arrowprops=dict(arrowstyle="simple", lw=1.5, color='black'))

# Center "Weighted Probability" annotation
plt.annotate('Weighted\nProbability', xy=(0.5, 0.3), xycoords='figure fraction', fontsize=14, ha='center', 
             bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="lightgray"))

# Display the figure
plt.tight_layout()
plt.show()
# Out:
# /scratch/local/8501612/ipykernel_1243751/1129693117.py:60: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Data for the matrices
current_climate = np.array([[0.8, 0.3], [0.5, 0.6]])
future_climate = np.array([[0.9, 0.2], [0.5, 0.5]])
climate_only_change = future_climate - current_climate

current_land_use = np.array([[0, 1], [1, 0]])
future_land_use = np.array([[0, 1], [1, 1]])
land_use_only_change = future_land_use - current_land_use

current_climate_land_use = np.array([[0, 0.3], [0.5, 0]])
future_climate_land_use = np.array([[0, 0.2], [0.5, 0.5]])
climate_land_use_change = future_climate_land_use - current_climate_land_use

# Create the subplots for all the different conditions
fig, axes = plt.subplots(3, 3, figsize=(12, 8))

# Plot current climate
sns.heatmap(current_climate, ax=axes[0, 0], cmap='Blues', annot=True, cbar=False)
axes[0, 0].set_title('Current climate')

# Plot future climate
sns.heatmap(future_climate, ax=axes[0, 1], cmap='Blues', annot=True, cbar=False)
axes[0, 1].set_title('Future climate')

# Plot climate-only change
sns.heatmap(climate_only_change, ax=axes[0, 2], cmap='RdBu', annot=True, cbar=False, center=0)
axes[0, 2].set_title('Climate only change')

# Plot current land use
sns.heatmap(current_land_use, ax=axes[1, 0], cmap='Blues', annot=True, cbar=False)
axes[1, 0].set_title('Current land-use')

# Plot future land use
sns.heatmap(future_land_use, ax=axes[1, 1], cmap='Blues', annot=True, cbar=False)
axes[1, 1].set_title('Future land-use')

# Plot land-use only change
sns.heatmap(land_use_only_change, ax=axes[1, 2], cmap='RdBu', annot=True, cbar=False, center=0)
axes[1, 2].set_title('LU only change')

# Plot current climate and land use
sns.heatmap(current_climate_land_use, ax=axes[2, 0], cmap='Blues', annot=True, cbar=False)
axes[2, 0].set_title('Current climate & land-use')

# Plot future climate and land use
sns.heatmap(future_climate_land_use, ax=axes[2, 1], cmap='Blues', annot=True, cbar=False)
axes[2, 1].set_title('Future climate & land-use')

# Plot climate and land-use change
sns.heatmap(climate_land_use_change, ax=axes[2, 2], cmap='RdBu', annot=True, cbar=False, center=0)
axes[2, 2].set_title('Climate & LU change')

# Adjust layout
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

# Add text annotations (like arrows)
fig.text(0.65, 0.9, 'Probability of occurrence', fontsize=12, ha='center')
plt.tight_layout()

# Show the final plot
plt.show()
