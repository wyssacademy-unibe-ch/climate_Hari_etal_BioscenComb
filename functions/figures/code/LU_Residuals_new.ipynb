# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
current_climate = np.array([[0.8, 0.3], [0.5, 0.6]])
future_climate = np.array([[0.9, 0.2], [0.5, 0.5]])



current_landuse = np.array([[0, 1], [1, 0]])
future_landuse = np.array([[0, 1], [0, 1]])

current_climate_current_landuse = current_climate * current_landuse
future_climate_current_landuse = future_climate *current_landuse
climate_only = future_climate_current_landuse - current_climate_current_landuse

future_climate_future_landuse = future_climate * future_landuse
climate_landuse=future_climate_future_landuse - current_climate_current_landuse

land_use_only =climate_landuse- climate_only

# %%
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5))


sns.heatmap(future_climate_current_landuse, ax=axes[0], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Future Climate & Current Land Use ', fontsize=12)

sns.heatmap(current_climate_current_landuse, ax=axes[1], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('Current Climate & Current Land Use', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(climate_only, ax=axes[2], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate Change only', fontsize=12)


# Add equal signs between the plots
fig.text(0.33, 0.5, '-', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(6, 2.5))


sns.heatmap(future_landuse, ax=axes[0], cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Future Land Use', fontsize=12)

sns.heatmap(current_landuse, ax=axes[1], cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('Current Land Use ', fontsize=12)


# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(9, 2.5))


sns.heatmap(future_climate_future_landuse, ax=axes[0], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Future Climate and Land Use', fontsize=12)

sns.heatmap(current_climate_current_landuse, ax=axes[1], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('Current Climate and Land Use', fontsize=12)

# Plot SSP4-RCP6.0 heatmaps
sns.heatmap(climate_landuse, ax=axes[2], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate and Land Use Change', fontsize=12)


# Add equal signs between the plots
fig.text(0.33, 0.5, '-', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes.flat:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(3, 2.5))


sns.heatmap(land_use_only, ax=ax, cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
ax.set_title('Land Use Only', fontsize=12)


ax.set_xticks([])
ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# First Figure with three heatmaps
fig, axes = plt.subplots(1, 3, figsize=(10, 2.5))

fig.text(0.02, 0.99, 'B)', fontsize=16, ha='left', va='top',weight='bold')


sns.heatmap(future_climate_current_landuse, ax=axes[0], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Future Climate & Current Land Use', fontsize=12)

sns.heatmap(current_climate_current_landuse, ax=axes[1], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('Current Climate & Current Land Use', fontsize=12)

sns.heatmap(climate_only, ax=axes[2], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate Change only', fontsize=12)

# Add symbols between plots
fig.text(0.33, 0.5, '-', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# Second Figure with two heatmaps
fig, axes = plt.subplots(1, 2, figsize=(6, 2.5))

sns.heatmap(future_landuse, ax=axes[0], cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Future Land Use', fontsize=12)

sns.heatmap(current_landuse, ax=axes[1], cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('Current Land Use', fontsize=12)

# Adjust layout and remove ticks
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# Third Figure with three heatmaps
fig, axes = plt.subplots(1, 3, figsize=(10, 2.5))

sns.heatmap(future_climate_future_landuse, ax=axes[0], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[0].set_title('Future Climate and Land Use', fontsize=12)

sns.heatmap(current_climate_current_landuse, ax=axes[1], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[1].set_title('Current Climate and Land Use', fontsize=12)

sns.heatmap(climate_landuse, ax=axes[2], cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes[2].set_title('Climate and Land Use Change', fontsize=12)

# Add symbols between plots
fig.text(0.33, 0.5, '-', fontsize=16, ha='center', va='center')
fig.text(0.65, 0.5, '=', fontsize=16, ha='center', va='center')

# Adjust layout and remove ticks
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

fig.savefig("/storage/homefs/ch21o450/scripts/climate_Hari_etal_inprep/functions/figures/main_figures/new_method_LU_res.png", dpi=300)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a single large figure to contain all subplots
fig = plt.figure(figsize=(10, 8))

# First row with three heatmaps
axes1 = fig.add_subplot(3, 3, 1)
sns.heatmap(future_climate_current_landuse, ax=axes1, cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes1.set_title('Future Climate & Current Land Use', fontsize=12)
axes1.set_xticks([])
axes1.set_yticks([])

axes2 = fig.add_subplot(3, 3, 2)
sns.heatmap(current_climate_current_landuse, ax=axes2, cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes2.set_title('Current Climate & Current Land Use', fontsize=12)
axes2.set_xticks([])
axes2.set_yticks([])

axes3 = fig.add_subplot(3, 3, 3)
sns.heatmap(climate_only, ax=axes3, cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes3.set_title('Climate Change only', fontsize=12)
axes3.set_xticks([])
axes3.set_yticks([])

# Add symbols between plots in the first row
fig.text(0.335, 0.773, '-', fontsize=16, ha='center', va='center')
fig.text(0.655, 0.773, '=', fontsize=16, ha='center', va='center')
fig.text(0.02, 0.97, 'A', fontsize=16, ha='left', va='top', weight='bold')

# Second row with two heatmaps
axes4 = fig.add_subplot(3, 3, 4)
sns.heatmap(future_landuse, ax=axes4, cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes4.set_title('Future Land Use', fontsize=12)
axes4.set_xticks([])
axes4.set_yticks([])

axes5 = fig.add_subplot(3, 3, 5)
sns.heatmap(current_landuse, ax=axes5, cmap='Greens', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes5.set_title('Current Land Use', fontsize=12)
axes5.set_xticks([])
axes5.set_yticks([])

# Third row with three heatmaps
axes6 = fig.add_subplot(3, 3, 7)
sns.heatmap(future_climate_future_landuse, ax=axes6, cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes6.set_title('Future Climate and Land Use', fontsize=12)
axes6.set_xticks([])
axes6.set_yticks([])

axes7 = fig.add_subplot(3, 3, 8)
sns.heatmap(current_climate_current_landuse, ax=axes7, cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes7.set_title('Current Climate and Land Use', fontsize=12)
axes7.set_xticks([])
axes7.set_yticks([])

axes8 = fig.add_subplot(3, 3, 9)
sns.heatmap(climate_landuse, ax=axes8, cmap='Reds', annot=True, cbar=False, fmt='.2f', annot_kws={"size": 12}, square=True)
axes8.set_title('Climate and Land Use Change', fontsize=12)
axes8.set_xticks([])
axes8.set_yticks([])

fig.text(0.335, 0.1524, '-', fontsize=16, ha='center', va='center')
fig.text(0.655, 0.1524, '=', fontsize=16, ha='center', va='center')
# Adjust layout to prevent overlap
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Save the combined figure as a single image
fig.savefig("/storage/homefs/ch21o450/scripts/climate_Hari_etal_inprep/functions/figures/main_figures/new_method_LU_res_test.png", dpi=300)
plt.show()
